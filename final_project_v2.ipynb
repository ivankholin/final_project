# %% [markdown]
# ### модель

# %%
# подгружаемые библиотеки
import numpy as np
import tensorflow as tf
import re

from bpemb import BPEmb

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
vocab_size = 5000 #размер словоря
emb_dim = 200 #размер эмбендингов
max_len = 200 # TODO посчитать максимальную длинну выборки
buffer_size = 5# размер буфера данных в батчах

# %%
bpemb_ru = BPEmb(lang='ru', vs=vocab_size , dim=emb_dim)

# bpemb_ru.encode_ids('.,!?:;-')
#>>> [2922, 2921, 2978, 2985, 2947, 2963, 2936]
def load_emb_matrix(bpemb= bpemb_ru, dtype=np.float32):
    '''функция загрузки эмбендингов в модель'''
    
    return bpemb.emb.vectors.astype(dtype)

def parse_fn(line, bpemb = bpemb_ru):
    '''
        функция кодировки строки:
        line- строка
    '''
    sequence = np.array(bpemb.encode_ids(line) + [0]).astype(np.int32)
    punct_dic = {4922: 1, 4921: 2, 4978: 3, 4985: 4, 4947: 5, 4963: 6, 4936: 7}
    feature = []
    label = []

    for i in range(len(sequence) - 1):
        if sequence[i] not in punct_dic:
            feature.append(sequence[i])
            if sequence[i + 1] in punct_dic:
                label.append(punct_dic[sequence[i + 1]])
            else:
                label.append(0)
                
    feature = np.array(feature).astype(np.int32)
    label = np.array(label).astype(np.int32)

    mask = ((label == 0)*0.6 + (label != 0)).astype(np.float32)
    
    return (feature, len(feature)), (label, len(label), mask)


def generator_fn(data_file_url):
    '''генератор чтения строк из файла и
        преобразования из в последовательности'''
    with open(data_file_url, 'r') as file:
        for row in file:
            yield parse_fn(row[:-1])


def input_fn(data_file_url, params, mode):
    '''функция подачи данных в модель,
        на вход получает адрес файла'''
    shapes = (([None], ()), ([None], (), [None]))
    types = ((tf.int32, tf.int32), (tf.int32, tf.int32, tf.float32))
    defaults = ((0, 0), (0, 0, 0.))

    dataset = tf.data.Dataset.from_generator(lambda : generator_fn(data_file_url),
                                             output_shapes=shapes, output_types=types)
    

    if mode == 'train':
        dataset = dataset.shuffle(buffer_size=params['train_size'], reshuffle_each_iteration=True)
        dataset = dataset.repeat(params['num_epochs'])
        dataset = dataset.repeat()

    return dataset.padded_batch(params['batch_size'], shapes, defaults).prefetch(params['train_size'])    

def test_genarator_fn(data, bpemb=bpemb_ru):
    '''генератор преобразования массива стор
        в массив последовательностей'''
    for line in data:
        sequence = bpemb_ru.encode_ids(line)
        yield (np.array(sequence).astype(np.int32), len(sequence)), 0

def test_input_fn(data, params):
    '''функция подачи данных в модель для теста
        на вход получает массив строк'''
    shapes = ([None], ()), ()
    types = (tf.int32, tf.int32), tf.int32
    defaults = (0, 0), 0

    dataset = tf.data.Dataset.from_generator(lambda : test_genarator_fn(data),
                                             output_shapes=shapes, output_types=types)
    
    return dataset.padded_batch(params['batch_size'], shapes, defaults).prefetch(1)

# %%
# модель
def model_fn(features, labels, mode, params):
    
    sequences, lengths = features
    current_butch_size = tf.shape(sequences)[0]

    # матрица эмбеддингов decoder-а
    embeddings = tf.Variable(initial_value = load_emb_matrix() ,trainable=False)
    
    embeded = tf.nn.embedding_lookup(params=embeddings, ids=sequences)
    
    
    bi_cell_fw  = tf.nn.rnn_cell.MultiRNNCell([tf.nn.rnn_cell.GRUCell(num_units=params['lstm_hidden_dim']) 
                          for _ in range(params['num_layers'])])

    bi_cell_bw  = tf.nn.rnn_cell.MultiRNNCell([tf.nn.rnn_cell.GRUCell(num_units=params['lstm_hidden_dim']) 
                          for _ in range(params['num_layers'])])   
    
    
    outputs, states = tf.nn.bidirectional_dynamic_rnn(   
                                                         bi_cell_fw,
                                                         bi_cell_bw,
                                                         embeded, 
                                                         sequence_length=lengths, 
                                                         dtype=tf.float32
                                                     )
    #prepare state
    output_fw, output_bw = outputs
    
    output = tf.concat([output_fw, output_bw], axis=-1)
    
    training = mode == tf.estimator.ModeKeys.TRAIN
    dropout = tf.layers.dropout(inputs=output, 
                                rate= params['dropout_rate'], 
                                training=training)
    
    lstm_cell = tf.nn.rnn_cell.LSTMCell(num_units=params['lstm_hidden_dim'])
    
    
    outputs_lstm, _ = tf.nn.dynamic_rnn(lstm_cell, dropout, sequence_length=lengths, dtype=tf.float32)
    
#    training = mode == tf.estimator.ModeKeys.TRAIN
#    dropout = tf.layers.dropout(inputs=outputs.rnn_output, 
#                                rate= params['dropout_rate'], 
#                                training=training)
#    

                                
    dense1 = tf.layers.dense(outputs_lstm, params['lstm_hidden_dim'], activation=tf.math.tanh)

    dense2 = tf.layers.dense(dense1, params['output_vocab_size'])
    

    logits = dense2
    sample_id = tf.argmax(logits, 2)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        predictions = {
            'sequences': sequences,
            'prediction': sample_id,
            'lengths': lengths
        }

        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)
    else:
        target, target_lengths, mask = labels

        #mask = tf.sequence_mask(lengths, dtype=tf.float32)


        loss = tf.contrib.seq2seq.sequence_loss(logits=logits, 
                                                targets=target, 
                                                weights=mask, 
                                                average_across_timesteps=True, 
                                                average_across_batch=True)

        # в режиме eval возвращаем усреднённый лосс
        if mode == tf.estimator.ModeKeys.EVAL:
            mask = tf.sequence_mask(lengths, dtype=tf.float32)
            metrics = {
                'acc': tf.metrics.accuracy(target, sample_id, mask),
                #'f1_score' : tf.contrib.metrics.f1_score(target, sample_id, mask),
            }
            
            return tf.estimator.EstimatorSpec(mode, loss=loss, eval_metric_ops=metrics)

        # в режиме train ещё и обновляем обучаемые параметры
        elif mode == tf.estimator.ModeKeys.TRAIN:
            optimizer = tf.train.AdamOptimizer
            optimizer = optimizer(learning_rate=params['learning_rate'])
            train_op = optimizer.minimize(loss, global_step=tf.train.get_global_step())

            return tf.estimator.EstimatorSpec(mode, loss=loss, train_op=train_op)

# %%
params = {
    'vocab_size': vocab_size,
    'output_vocab_size': 8,
    'train_size': 256*buffer_size,
    'num_layers': 2,
    'embedding_dim': emb_dim,
    'dropout_rate': 0.2,
    'lstm_hidden_dim': 512,
    'max_iter': max_len,
    'batch_size': 256,
    'num_epochs': 1,
    'learning_rate': 1e-3
}

config = tf.estimator.RunConfig(model_dir='project_v2_2',
                                save_checkpoints_steps = 200,
                               save_checkpoints_secs = None)
model = tf.estimator.Estimator(model_fn=model_fn, params=params, config=config)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'project_v2_2', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 200, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f0652c66358>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(lambda: input_fn('flibusta_full_train.txt', params=params, mode='train'))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into project_v2_2/model.ckpt.
# INFO:tensorflow:loss = 2.0704308, step = 1
# INFO:tensorflow:global_step/sec: 0.206115
# INFO:tensorflow:loss = 0.6540087, step = 101 (485.168 sec)
# INFO:tensorflow:Saving checkpoints for 200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.222026
# INFO:tensorflow:loss = 0.46706274, step = 201 (450.398 sec)
# INFO:tensorflow:global_step/sec: 0.228938
# INFO:tensorflow:loss = 0.39895663, step = 301 (436.800 sec)
# INFO:tensorflow:Saving checkpoints for 400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.229738
# INFO:tensorflow:loss = 0.3054805, step = 401 (435.277 sec)
# INFO:tensorflow:global_step/sec: 0.223954
# INFO:tensorflow:loss = 0.32328272, step = 501 (446.520 sec)
# INFO:tensorflow:Saving checkpoints for 600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.222414
# INFO:tensorflow:loss = 0.31962693, step = 601 (449.613 sec)
# INFO:tensorflow:global_step/sec: 0.22599
# INFO:tensorflow:loss = 0.29094112, step = 701 (442.497 sec)
# INFO:tensorflow:Saving checkpoints for 800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.227512
# INFO:tensorflow:loss = 0.3191771, step = 801 (439.537 sec)
# INFO:tensorflow:global_step/sec: 0.188925
# INFO:tensorflow:loss = 0.3974702, step = 901 (529.312 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.233219
# INFO:tensorflow:loss = 0.38034382, step = 1001 (428.781 sec)
# INFO:tensorflow:global_step/sec: 0.233088
# INFO:tensorflow:loss = 0.331906, step = 1101 (429.022 sec)
# INFO:tensorflow:Saving checkpoints for 1200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.18457
# INFO:tensorflow:loss = 0.33234105, step = 1201 (541.798 sec)
# INFO:tensorflow:global_step/sec: 0.215193
# INFO:tensorflow:loss = 0.34552127, step = 1301 (464.698 sec)
# INFO:tensorflow:Saving checkpoints for 1400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.222589
# INFO:tensorflow:loss = 0.33433226, step = 1401 (449.259 sec)
# INFO:tensorflow:global_step/sec: 0.203279
# INFO:tensorflow:loss = 0.32554218, step = 1501 (491.935 sec)
# INFO:tensorflow:Saving checkpoints for 1600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.184655
# INFO:tensorflow:loss = 0.33738557, step = 1601 (541.549 sec)
# INFO:tensorflow:global_step/sec: 0.201483
# INFO:tensorflow:loss = 0.33190683, step = 1701 (496.320 sec)
# INFO:tensorflow:Saving checkpoints for 1800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.199213
# INFO:tensorflow:loss = 0.30506945, step = 1801 (501.976 sec)
# INFO:tensorflow:global_step/sec: 0.192034
# INFO:tensorflow:loss = 0.24270405, step = 1901 (520.742 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.194174
# INFO:tensorflow:loss = 0.29221073, step = 2001 (515.002 sec)
# INFO:tensorflow:global_step/sec: 0.175169
# INFO:tensorflow:loss = 0.35719907, step = 2101 (570.877 sec)
# INFO:tensorflow:Saving checkpoints for 2200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.191233
# INFO:tensorflow:loss = 0.29723203, step = 2201 (522.922 sec)
# INFO:tensorflow:global_step/sec: 0.185873
# INFO:tensorflow:loss = 0.31828892, step = 2301 (538.003 sec)
# INFO:tensorflow:Saving checkpoints for 2400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.207583
# INFO:tensorflow:loss = 0.3078632, step = 2401 (481.735 sec)
# INFO:tensorflow:global_step/sec: 0.194279
# INFO:tensorflow:loss = 0.2905308, step = 2501 (514.724 sec)
# INFO:tensorflow:Saving checkpoints for 2600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.198254
# INFO:tensorflow:loss = 0.3638957, step = 2601 (504.402 sec)
# INFO:tensorflow:global_step/sec: 0.193973
# INFO:tensorflow:loss = 0.3086747, step = 2701 (515.536 sec)
# INFO:tensorflow:Saving checkpoints for 2800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.181493
# INFO:tensorflow:loss = 0.23954362, step = 2801 (550.984 sec)
# INFO:tensorflow:global_step/sec: 0.18231
# INFO:tensorflow:loss = 0.2631041, step = 2901 (548.515 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.201617
# INFO:tensorflow:loss = 0.27888942, step = 3001 (495.990 sec)
# INFO:tensorflow:global_step/sec: 0.182387
# INFO:tensorflow:loss = 0.3351321, step = 3101 (548.284 sec)
# INFO:tensorflow:Saving checkpoints for 3200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.175839
# INFO:tensorflow:loss = 0.2773975, step = 3201 (568.703 sec)
# INFO:tensorflow:global_step/sec: 0.188586
# INFO:tensorflow:loss = 0.28146568, step = 3301 (530.262 sec)
# INFO:tensorflow:Saving checkpoints for 3400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.179395
# INFO:tensorflow:loss = 0.24932212, step = 3401 (557.431 sec)
# INFO:tensorflow:global_step/sec: 0.199056
# INFO:tensorflow:loss = 0.26875225, step = 3501 (502.370 sec)
# INFO:tensorflow:Saving checkpoints for 3600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.202406
# INFO:tensorflow:loss = 0.30836818, step = 3601 (494.058 sec)
# INFO:tensorflow:global_step/sec: 0.177541
# INFO:tensorflow:loss = 0.21133007, step = 3701 (563.250 sec)
# INFO:tensorflow:Saving checkpoints for 3800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.1896
# INFO:tensorflow:loss = 0.23541725, step = 3801 (527.425 sec)
# INFO:tensorflow:global_step/sec: 0.180092
# INFO:tensorflow:loss = 0.23692971, step = 3901 (555.273 sec)
# INFO:tensorflow:Saving checkpoints for 4000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.213696
# INFO:tensorflow:loss = 0.3158224, step = 4001 (467.952 sec)
# INFO:tensorflow:global_step/sec: 0.208111
# INFO:tensorflow:loss = 0.32348582, step = 4101 (480.512 sec)
# INFO:tensorflow:Saving checkpoints for 4200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.188465
# INFO:tensorflow:loss = 0.15750006, step = 4201 (530.602 sec)
# INFO:tensorflow:global_step/sec: 0.192101
# INFO:tensorflow:loss = 0.32601398, step = 4301 (520.560 sec)
# INFO:tensorflow:Saving checkpoints for 4400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.216797
# INFO:tensorflow:loss = 0.25609413, step = 4401 (461.261 sec)
# INFO:tensorflow:global_step/sec: 0.218552
# INFO:tensorflow:loss = 0.24098253, step = 4501 (457.557 sec)
# INFO:tensorflow:Saving checkpoints for 4600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.186161
# INFO:tensorflow:loss = 0.25502804, step = 4601 (537.168 sec)
# INFO:tensorflow:global_step/sec: 0.185367
# INFO:tensorflow:loss = 0.2394646, step = 4701 (539.472 sec)
# INFO:tensorflow:Saving checkpoints for 4800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.187167
# INFO:tensorflow:loss = 0.28007063, step = 4801 (534.281 sec)
# INFO:tensorflow:global_step/sec: 0.226556
# INFO:tensorflow:loss = 0.24083456, step = 4901 (441.392 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.23103
# INFO:tensorflow:loss = 0.20619404, step = 5001 (432.844 sec)
# INFO:tensorflow:global_step/sec: 0.218713
# INFO:tensorflow:loss = 0.27572188, step = 5101 (457.219 sec)
# INFO:tensorflow:Saving checkpoints for 5200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.211344
# INFO:tensorflow:loss = 0.26728612, step = 5201 (473.163 sec)
# INFO:tensorflow:global_step/sec: 0.224479
# INFO:tensorflow:loss = 0.2741567, step = 5301 (445.475 sec)
# INFO:tensorflow:Saving checkpoints for 5400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.216978
# INFO:tensorflow:loss = 0.34110767, step = 5401 (460.875 sec)
# INFO:tensorflow:global_step/sec: 0.214961
# INFO:tensorflow:loss = 0.3035994, step = 5501 (465.201 sec)
# INFO:tensorflow:Saving checkpoints for 5600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.217282
# INFO:tensorflow:loss = 0.2696202, step = 5601 (460.230 sec)
# INFO:tensorflow:global_step/sec: 0.216332
# INFO:tensorflow:loss = 0.24245346, step = 5701 (462.253 sec)
# INFO:tensorflow:Saving checkpoints for 5800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.219153
# INFO:tensorflow:loss = 0.29320988, step = 5801 (456.302 sec)
# INFO:tensorflow:global_step/sec: 0.215769
# INFO:tensorflow:loss = 0.29620254, step = 5901 (463.459 sec)
# INFO:tensorflow:Saving checkpoints for 6000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.24024
# INFO:tensorflow:loss = 0.29398084, step = 6001 (416.251 sec)
# INFO:tensorflow:global_step/sec: 0.226633
# INFO:tensorflow:loss = 0.26217553, step = 6101 (441.243 sec)
# INFO:tensorflow:Saving checkpoints for 6200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.225964
# INFO:tensorflow:loss = 0.24495342, step = 6201 (442.550 sec)
# INFO:tensorflow:global_step/sec: 0.229445
# INFO:tensorflow:loss = 0.24014305, step = 6301 (435.834 sec)
# INFO:tensorflow:Saving checkpoints for 6400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.247402
# INFO:tensorflow:loss = 0.29357684, step = 6401 (404.200 sec)
# INFO:tensorflow:global_step/sec: 0.241343
# INFO:tensorflow:loss = 0.27072343, step = 6501 (414.348 sec)
# INFO:tensorflow:Saving checkpoints for 6600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.249352
# INFO:tensorflow:loss = 0.22788234, step = 6601 (401.039 sec)
# INFO:tensorflow:global_step/sec: 0.235391
# INFO:tensorflow:loss = 0.20103803, step = 6701 (424.825 sec)
# INFO:tensorflow:Saving checkpoints for 6800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.243624
# INFO:tensorflow:loss = 0.26281855, step = 6801 (410.468 sec)
# INFO:tensorflow:global_step/sec: 0.251638
# INFO:tensorflow:loss = 0.3288762, step = 6901 (397.397 sec)
# INFO:tensorflow:Saving checkpoints for 7000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.248271
# INFO:tensorflow:loss = 0.19775656, step = 7001 (402.785 sec)
# INFO:tensorflow:global_step/sec: 0.249294
# INFO:tensorflow:loss = 0.31916055, step = 7101 (401.133 sec)
# INFO:tensorflow:Saving checkpoints for 7200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.246121
# INFO:tensorflow:loss = 0.24902435, step = 7201 (406.304 sec)
# INFO:tensorflow:global_step/sec: 0.252713
# INFO:tensorflow:loss = 0.28268057, step = 7301 (395.706 sec)
# INFO:tensorflow:Saving checkpoints for 7400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.2507
# INFO:tensorflow:loss = 0.3277531, step = 7401 (398.883 sec)
# INFO:tensorflow:global_step/sec: 0.248643
# INFO:tensorflow:loss = 0.2963237, step = 7501 (402.183 sec)
# INFO:tensorflow:Saving checkpoints for 7600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.248426
# INFO:tensorflow:loss = 0.26065296, step = 7601 (402.535 sec)
# INFO:tensorflow:global_step/sec: 0.248315
# INFO:tensorflow:loss = 0.30171898, step = 7701 (402.714 sec)
# INFO:tensorflow:Saving checkpoints for 7800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.248941
# INFO:tensorflow:loss = 0.28563508, step = 7801 (401.702 sec)
# INFO:tensorflow:global_step/sec: 0.248622
# INFO:tensorflow:loss = 0.21496305, step = 7901 (402.218 sec)
# INFO:tensorflow:Saving checkpoints for 8000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.260415
# INFO:tensorflow:loss = 0.23113537, step = 8001 (384.002 sec)
# INFO:tensorflow:global_step/sec: 0.261387
# INFO:tensorflow:loss = 0.25523564, step = 8101 (382.575 sec)
# INFO:tensorflow:Saving checkpoints for 8200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.267025
# INFO:tensorflow:loss = 0.16732317, step = 8201 (374.497 sec)
# INFO:tensorflow:global_step/sec: 0.26258
# INFO:tensorflow:loss = 0.22589315, step = 8301 (380.836 sec)
# INFO:tensorflow:Saving checkpoints for 8400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.254071
# INFO:tensorflow:loss = 0.34643584, step = 8401 (393.591 sec)
# INFO:tensorflow:global_step/sec: 0.263485
# INFO:tensorflow:loss = 0.2333303, step = 8501 (379.528 sec)
# INFO:tensorflow:Saving checkpoints for 8600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.262683
# INFO:tensorflow:loss = 0.23734088, step = 8601 (380.687 sec)
# INFO:tensorflow:global_step/sec: 0.265602
# INFO:tensorflow:loss = 0.24687374, step = 8701 (376.504 sec)
# INFO:tensorflow:Saving checkpoints for 8800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.268072
# INFO:tensorflow:loss = 0.2657588, step = 8801 (373.033 sec)
# INFO:tensorflow:global_step/sec: 0.261247
# INFO:tensorflow:loss = 0.28242487, step = 8901 (382.780 sec)
# INFO:tensorflow:Saving checkpoints for 9000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.265622
# INFO:tensorflow:loss = 0.26544246, step = 9001 (376.475 sec)
# INFO:tensorflow:global_step/sec: 0.263073
# INFO:tensorflow:loss = 0.23979753, step = 9101 (380.123 sec)
# INFO:tensorflow:Saving checkpoints for 9200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.262618
# INFO:tensorflow:loss = 0.2804738, step = 9201 (380.782 sec)
# INFO:tensorflow:global_step/sec: 0.263633
# INFO:tensorflow:loss = 0.2446516, step = 9301 (379.315 sec)
# INFO:tensorflow:Saving checkpoints for 9400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261744
# INFO:tensorflow:loss = 0.2616609, step = 9401 (382.053 sec)
# INFO:tensorflow:global_step/sec: 0.263619
# INFO:tensorflow:loss = 0.1963319, step = 9501 (379.335 sec)
# INFO:tensorflow:Saving checkpoints for 9600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.26577
# INFO:tensorflow:loss = 0.22858426, step = 9601 (376.265 sec)
# INFO:tensorflow:global_step/sec: 0.265211
# INFO:tensorflow:loss = 0.23942189, step = 9701 (377.059 sec)
# INFO:tensorflow:Saving checkpoints for 9800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.264512
# INFO:tensorflow:loss = 0.16091381, step = 9801 (378.054 sec)
# INFO:tensorflow:global_step/sec: 0.26526
# INFO:tensorflow:loss = 0.28471118, step = 9901 (376.989 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.262038
# INFO:tensorflow:loss = 0.2060667, step = 10001 (381.624 sec)
# INFO:tensorflow:global_step/sec: 0.267293
# INFO:tensorflow:loss = 0.19624221, step = 10101 (374.121 sec)
# INFO:tensorflow:Saving checkpoints for 10200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.266755
# INFO:tensorflow:loss = 0.25667295, step = 10201 (374.876 sec)
# INFO:tensorflow:global_step/sec: 0.265855
# INFO:tensorflow:loss = 0.15590382, step = 10301 (376.146 sec)
# INFO:tensorflow:Saving checkpoints for 10400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261389
# INFO:tensorflow:loss = 0.30779904, step = 10401 (382.571 sec)
# INFO:tensorflow:global_step/sec: 0.264386
# INFO:tensorflow:loss = 0.2600993, step = 10501 (378.235 sec)
# INFO:tensorflow:Saving checkpoints for 10600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.264495
# INFO:tensorflow:loss = 0.24877883, step = 10601 (378.079 sec)
# INFO:tensorflow:global_step/sec: 0.264929
# INFO:tensorflow:loss = 0.23800138, step = 10701 (377.459 sec)
# INFO:tensorflow:Saving checkpoints for 10800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.26199
# INFO:tensorflow:loss = 0.15650778, step = 10801 (381.694 sec)
# INFO:tensorflow:global_step/sec: 0.266304
# INFO:tensorflow:loss = 0.2847997, step = 10901 (375.511 sec)
# INFO:tensorflow:Saving checkpoints for 11000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261207
# INFO:tensorflow:loss = 0.24345747, step = 11001 (382.838 sec)
# INFO:tensorflow:global_step/sec: 0.265212
# INFO:tensorflow:loss = 0.23373137, step = 11101 (377.057 sec)
# INFO:tensorflow:Saving checkpoints for 11200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.255854
# INFO:tensorflow:loss = 0.2483471, step = 11201 (390.847 sec)
# INFO:tensorflow:global_step/sec: 0.252192
# INFO:tensorflow:loss = 0.1833571, step = 11301 (396.524 sec)
# INFO:tensorflow:Saving checkpoints for 11400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.2663
# INFO:tensorflow:loss = 0.18703036, step = 11401 (375.516 sec)
# INFO:tensorflow:global_step/sec: 0.262827
# INFO:tensorflow:loss = 0.2575367, step = 11501 (380.479 sec)
# INFO:tensorflow:Saving checkpoints for 11600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.265727
# INFO:tensorflow:loss = 0.17987627, step = 11601 (376.326 sec)
# INFO:tensorflow:global_step/sec: 0.263762
# INFO:tensorflow:loss = 0.22028692, step = 11701 (379.129 sec)
# INFO:tensorflow:Saving checkpoints for 11800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.26248
# INFO:tensorflow:loss = 0.209353, step = 11801 (380.981 sec)
# INFO:tensorflow:global_step/sec: 0.263716
# INFO:tensorflow:loss = 0.18974131, step = 11901 (379.197 sec)
# INFO:tensorflow:Saving checkpoints for 12000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.264481
# INFO:tensorflow:loss = 0.23417684, step = 12001 (378.099 sec)
# INFO:tensorflow:global_step/sec: 0.264056
# INFO:tensorflow:loss = 0.30757982, step = 12101 (378.707 sec)
# INFO:tensorflow:Saving checkpoints for 12200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.26141
# INFO:tensorflow:loss = 0.23953158, step = 12201 (382.541 sec)
# INFO:tensorflow:global_step/sec: 0.265119
# INFO:tensorflow:loss = 0.34901983, step = 12301 (377.189 sec)
# INFO:tensorflow:Saving checkpoints for 12400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.259101
# INFO:tensorflow:loss = 0.3023941, step = 12401 (385.950 sec)
# INFO:tensorflow:global_step/sec: 0.267119
# INFO:tensorflow:loss = 0.29336756, step = 12501 (374.366 sec)
# INFO:tensorflow:Saving checkpoints for 12600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.263266
# INFO:tensorflow:loss = 0.20286474, step = 12601 (379.844 sec)
# INFO:tensorflow:global_step/sec: 0.267075
# INFO:tensorflow:loss = 0.3637063, step = 12701 (374.427 sec)
# INFO:tensorflow:Saving checkpoints for 12800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.264496
# INFO:tensorflow:loss = 0.21922287, step = 12801 (378.078 sec)
# INFO:tensorflow:global_step/sec: 0.263516
# INFO:tensorflow:loss = 0.288639, step = 12901 (379.483 sec)
# INFO:tensorflow:Saving checkpoints for 13000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.263254
# INFO:tensorflow:loss = 0.2247464, step = 13001 (379.861 sec)
# INFO:tensorflow:global_step/sec: 0.267567
# INFO:tensorflow:loss = 0.27492666, step = 13101 (373.738 sec)
# INFO:tensorflow:Saving checkpoints for 13200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261802
# INFO:tensorflow:loss = 0.2250354, step = 13201 (381.968 sec)
# INFO:tensorflow:global_step/sec: 0.264711
# INFO:tensorflow:loss = 0.18676475, step = 13301 (377.770 sec)
# INFO:tensorflow:Saving checkpoints for 13400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.264764
# INFO:tensorflow:loss = 0.27837923, step = 13401 (377.695 sec)
# INFO:tensorflow:global_step/sec: 0.266613
# INFO:tensorflow:loss = 0.21600626, step = 13501 (375.076 sec)
# INFO:tensorflow:Saving checkpoints for 13600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.264048
# INFO:tensorflow:loss = 0.23152108, step = 13601 (378.719 sec)
# INFO:tensorflow:global_step/sec: 0.268881
# INFO:tensorflow:loss = 0.28227267, step = 13701 (371.911 sec)
# INFO:tensorflow:Saving checkpoints for 13800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.263652
# INFO:tensorflow:loss = 0.28291765, step = 13801 (379.288 sec)
# INFO:tensorflow:global_step/sec: 0.247721
# INFO:tensorflow:loss = 0.2842598, step = 13901 (403.680 sec)
# INFO:tensorflow:Saving checkpoints for 14000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.262651
# INFO:tensorflow:loss = 0.24202125, step = 14001 (380.735 sec)
# INFO:tensorflow:global_step/sec: 0.261746
# INFO:tensorflow:loss = 0.28756544, step = 14101 (382.050 sec)
# INFO:tensorflow:Saving checkpoints for 14200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.262529
# INFO:tensorflow:loss = 0.30385974, step = 14201 (380.910 sec)
# INFO:tensorflow:global_step/sec: 0.265918
# INFO:tensorflow:loss = 0.25192216, step = 14301 (376.055 sec)
# INFO:tensorflow:Saving checkpoints for 14400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.260805
# INFO:tensorflow:loss = 0.28204608, step = 14401 (383.428 sec)
# INFO:tensorflow:global_step/sec: 0.263723
# INFO:tensorflow:loss = 0.25770748, step = 14501 (379.186 sec)
# INFO:tensorflow:Saving checkpoints for 14600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.269263
# INFO:tensorflow:loss = 0.27760088, step = 14601 (371.384 sec)
# INFO:tensorflow:global_step/sec: 0.261399
# INFO:tensorflow:loss = 0.27358136, step = 14701 (382.556 sec)
# INFO:tensorflow:Saving checkpoints for 14800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.262693
# INFO:tensorflow:loss = 0.2993397, step = 14801 (380.673 sec)
# INFO:tensorflow:global_step/sec: 0.263667
# INFO:tensorflow:loss = 0.32068914, step = 14901 (379.266 sec)
# INFO:tensorflow:Saving checkpoints for 15000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.260374
# INFO:tensorflow:loss = 0.20138162, step = 15001 (384.063 sec)
# INFO:tensorflow:global_step/sec: 0.264588
# INFO:tensorflow:loss = 0.29430613, step = 15101 (377.946 sec)
# INFO:tensorflow:Saving checkpoints for 15200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.266021
# INFO:tensorflow:loss = 0.32216495, step = 15201 (375.909 sec)
# INFO:tensorflow:global_step/sec: 0.26812
# INFO:tensorflow:loss = 0.20303756, step = 15301 (372.967 sec)
# INFO:tensorflow:Saving checkpoints for 15400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261382
# INFO:tensorflow:loss = 0.22279753, step = 15401 (382.582 sec)
# INFO:tensorflow:global_step/sec: 0.265758
# INFO:tensorflow:loss = 0.25089884, step = 15501 (376.282 sec)
# INFO:tensorflow:Saving checkpoints for 15600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.251784
# INFO:tensorflow:loss = 0.284521, step = 15601 (397.165 sec)
# INFO:tensorflow:global_step/sec: 0.242053
# INFO:tensorflow:loss = 0.27383497, step = 15701 (413.132 sec)
# INFO:tensorflow:Saving checkpoints for 15800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.241179
# INFO:tensorflow:loss = 0.19466002, step = 15801 (414.630 sec)
# INFO:tensorflow:global_step/sec: 0.239027
# INFO:tensorflow:loss = 0.26691583, step = 15901 (418.364 sec)
# INFO:tensorflow:Saving checkpoints for 16000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.237899
# INFO:tensorflow:loss = 0.2677492, step = 16001 (420.346 sec)
# INFO:tensorflow:global_step/sec: 0.250961
# INFO:tensorflow:loss = 0.24306193, step = 16101 (398.469 sec)
# INFO:tensorflow:Saving checkpoints for 16200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.249101
# INFO:tensorflow:loss = 0.27513537, step = 16201 (401.444 sec)
# INFO:tensorflow:global_step/sec: 0.248283
# INFO:tensorflow:loss = 0.2960542, step = 16301 (402.766 sec)
# INFO:tensorflow:Saving checkpoints for 16400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.237197
# INFO:tensorflow:loss = 0.2465309, step = 16401 (421.590 sec)
# INFO:tensorflow:global_step/sec: 0.250494
# INFO:tensorflow:loss = 0.22708184, step = 16501 (399.211 sec)
# INFO:tensorflow:Saving checkpoints for 16600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.249938
# INFO:tensorflow:loss = 0.25124368, step = 16601 (400.100 sec)
# INFO:tensorflow:global_step/sec: 0.254003
# INFO:tensorflow:loss = 0.26316804, step = 16701 (393.696 sec)
# INFO:tensorflow:Saving checkpoints for 16800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.25453
# INFO:tensorflow:loss = 0.259491, step = 16801 (392.881 sec)
# INFO:tensorflow:global_step/sec: 0.2441
# INFO:tensorflow:loss = 0.26515976, step = 16901 (409.668 sec)
# INFO:tensorflow:Saving checkpoints for 17000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.257491
# INFO:tensorflow:loss = 0.23641674, step = 17001 (388.362 sec)
# INFO:tensorflow:global_step/sec: 0.263316
# INFO:tensorflow:loss = 0.23239034, step = 17101 (379.773 sec)
# INFO:tensorflow:Saving checkpoints for 17200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.237772
# INFO:tensorflow:loss = 0.2805977, step = 17201 (420.571 sec)
# INFO:tensorflow:global_step/sec: 0.22923
# INFO:tensorflow:loss = 0.25582767, step = 17301 (436.243 sec)
# INFO:tensorflow:Saving checkpoints for 17400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.220882
# INFO:tensorflow:loss = 0.23812766, step = 17401 (452.731 sec)
# INFO:tensorflow:global_step/sec: 0.22457
# INFO:tensorflow:loss = 0.27350432, step = 17501 (445.295 sec)
# INFO:tensorflow:Saving checkpoints for 17600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.223505
# INFO:tensorflow:loss = 0.24015555, step = 17601 (447.417 sec)
# INFO:tensorflow:global_step/sec: 0.229447
# INFO:tensorflow:loss = 0.19238351, step = 17701 (435.831 sec)
# INFO:tensorflow:Saving checkpoints for 17800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.221017
# INFO:tensorflow:loss = 0.29083875, step = 17801 (452.453 sec)
# INFO:tensorflow:global_step/sec: 0.227578
# INFO:tensorflow:loss = 0.23398647, step = 17901 (439.410 sec)
# INFO:tensorflow:Saving checkpoints for 18000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.246005
# INFO:tensorflow:loss = 0.20238511, step = 18001 (406.495 sec)
# INFO:tensorflow:global_step/sec: 0.241368
# INFO:tensorflow:loss = 0.21024208, step = 18101 (414.306 sec)
# INFO:tensorflow:Saving checkpoints for 18200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.222527
# INFO:tensorflow:loss = 0.24609679, step = 18201 (449.383 sec)
# INFO:tensorflow:global_step/sec: 0.243089
# INFO:tensorflow:loss = 0.27261278, step = 18301 (411.373 sec)
# INFO:tensorflow:Saving checkpoints for 18400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.246721
# INFO:tensorflow:loss = 0.195736, step = 18401 (405.315 sec)
# INFO:tensorflow:global_step/sec: 0.243101
# INFO:tensorflow:loss = 0.23228581, step = 18501 (411.351 sec)
# INFO:tensorflow:Saving checkpoints for 18600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.2409
# INFO:tensorflow:loss = 0.2492252, step = 18601 (415.109 sec)
# INFO:tensorflow:global_step/sec: 0.236455
# INFO:tensorflow:loss = 0.24773838, step = 18701 (422.914 sec)
# INFO:tensorflow:Saving checkpoints for 18800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.239264
# INFO:tensorflow:loss = 0.18912199, step = 18801 (417.948 sec)
# INFO:tensorflow:global_step/sec: 0.239145
# INFO:tensorflow:loss = 0.2675612, step = 18901 (418.157 sec)
# INFO:tensorflow:Saving checkpoints for 19000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.23833
# INFO:tensorflow:loss = 0.22673853, step = 19001 (419.587 sec)
# INFO:tensorflow:global_step/sec: 0.23545
# INFO:tensorflow:loss = 0.26952904, step = 19101 (424.720 sec)
# INFO:tensorflow:Saving checkpoints for 19200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.235883
# INFO:tensorflow:loss = 0.18705872, step = 19201 (423.938 sec)
# INFO:tensorflow:global_step/sec: 0.222122
# INFO:tensorflow:loss = 0.2744236, step = 19301 (450.202 sec)
# INFO:tensorflow:Saving checkpoints for 19400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.251417
# INFO:tensorflow:loss = 0.25550863, step = 19401 (397.745 sec)
# INFO:tensorflow:global_step/sec: 0.233565
# INFO:tensorflow:loss = 0.27796036, step = 19501 (428.146 sec)
# INFO:tensorflow:Saving checkpoints for 19600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.236013
# INFO:tensorflow:loss = 0.26914766, step = 19601 (423.705 sec)
# INFO:tensorflow:global_step/sec: 0.230732
# INFO:tensorflow:loss = 0.31978187, step = 19701 (433.404 sec)
# INFO:tensorflow:Saving checkpoints for 19800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.230306
# INFO:tensorflow:loss = 0.2666002, step = 19801 (434.205 sec)
# INFO:tensorflow:global_step/sec: 0.24135
# INFO:tensorflow:loss = 0.24926262, step = 19901 (414.337 sec)
# INFO:tensorflow:Saving checkpoints for 20000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.238164
# INFO:tensorflow:loss = 0.18035278, step = 20001 (419.878 sec)
# INFO:tensorflow:global_step/sec: 0.232718
# INFO:tensorflow:loss = 0.21955746, step = 20101 (429.707 sec)
# INFO:tensorflow:Saving checkpoints for 20200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.203739
# INFO:tensorflow:loss = 0.19517587, step = 20201 (490.823 sec)
# INFO:tensorflow:global_step/sec: 0.178467
# INFO:tensorflow:loss = 0.22680533, step = 20301 (560.327 sec)
# INFO:tensorflow:Saving checkpoints for 20400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.161923
# INFO:tensorflow:loss = 0.28644043, step = 20401 (617.576 sec)
# INFO:tensorflow:global_step/sec: 0.177896
# INFO:tensorflow:loss = 0.20914397, step = 20501 (562.126 sec)
# INFO:tensorflow:Saving checkpoints for 20600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.174139
# INFO:tensorflow:loss = 0.24060537, step = 20601 (574.256 sec)
# INFO:tensorflow:global_step/sec: 0.182691
# INFO:tensorflow:loss = 0.20506692, step = 20701 (547.373 sec)
# INFO:tensorflow:Saving checkpoints for 20800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.175021
# INFO:tensorflow:loss = 0.25258446, step = 20801 (571.362 sec)
# INFO:tensorflow:global_step/sec: 0.211051
# INFO:tensorflow:loss = 0.19841556, step = 20901 (473.818 sec)
# INFO:tensorflow:Saving checkpoints for 21000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.233975
# INFO:tensorflow:loss = 0.26549107, step = 21001 (427.396 sec)
# INFO:tensorflow:global_step/sec: 0.225816
# INFO:tensorflow:loss = 0.21273147, step = 21101 (442.839 sec)
# INFO:tensorflow:Saving checkpoints for 21200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.229823
# INFO:tensorflow:loss = 0.2826851, step = 21201 (435.116 sec)
# INFO:tensorflow:global_step/sec: 0.232773
# INFO:tensorflow:loss = 0.17697714, step = 21301 (429.604 sec)
# INFO:tensorflow:Saving checkpoints for 21400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.23445
# INFO:tensorflow:loss = 0.23520106, step = 21401 (426.530 sec)
# INFO:tensorflow:global_step/sec: 0.213052
# INFO:tensorflow:loss = 0.22704919, step = 21501 (469.368 sec)
# INFO:tensorflow:Saving checkpoints for 21600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.181117
# INFO:tensorflow:loss = 0.2939481, step = 21601 (552.129 sec)
# INFO:tensorflow:global_step/sec: 0.177584
# INFO:tensorflow:loss = 0.22645123, step = 21701 (563.113 sec)
# INFO:tensorflow:Saving checkpoints for 21800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.181799
# INFO:tensorflow:loss = 0.24039741, step = 21801 (550.059 sec)
# INFO:tensorflow:global_step/sec: 0.190109
# INFO:tensorflow:loss = 0.28816986, step = 21901 (526.015 sec)
# INFO:tensorflow:Saving checkpoints for 22000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.202085
# INFO:tensorflow:loss = 0.300699, step = 22001 (494.843 sec)
# INFO:tensorflow:global_step/sec: 0.181741
# INFO:tensorflow:loss = 0.2570924, step = 22101 (550.232 sec)
# INFO:tensorflow:Saving checkpoints for 22200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.183017
# INFO:tensorflow:loss = 0.22000097, step = 22201 (546.400 sec)
# INFO:tensorflow:global_step/sec: 0.179533
# INFO:tensorflow:loss = 0.19724442, step = 22301 (556.999 sec)
# INFO:tensorflow:Saving checkpoints for 22400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.181973
# INFO:tensorflow:loss = 0.22746816, step = 22401 (549.532 sec)
# INFO:tensorflow:global_step/sec: 0.179683
# INFO:tensorflow:loss = 0.26250243, step = 22501 (556.537 sec)
# INFO:tensorflow:Saving checkpoints for 22600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.223957
# INFO:tensorflow:loss = 0.27660078, step = 22601 (446.514 sec)
# INFO:tensorflow:global_step/sec: 0.218981
# INFO:tensorflow:loss = 0.16562511, step = 22701 (456.667 sec)
# INFO:tensorflow:Saving checkpoints for 22800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.202956
# INFO:tensorflow:loss = 0.21471272, step = 22801 (492.713 sec)
# INFO:tensorflow:global_step/sec: 0.179612
# INFO:tensorflow:loss = 0.28323248, step = 22901 (556.757 sec)
# INFO:tensorflow:Saving checkpoints for 23000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.155122
# INFO:tensorflow:loss = 0.21855024, step = 23001 (644.655 sec)
# INFO:tensorflow:global_step/sec: 0.169095
# INFO:tensorflow:loss = 0.20139858, step = 23101 (591.385 sec)
# INFO:tensorflow:Saving checkpoints for 23200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.173998
# INFO:tensorflow:loss = 0.26319724, step = 23201 (574.720 sec)
# INFO:tensorflow:global_step/sec: 0.196534
# INFO:tensorflow:loss = 0.22789086, step = 23301 (508.818 sec)
# INFO:tensorflow:Saving checkpoints for 23400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.236917
# INFO:tensorflow:loss = 0.25947487, step = 23401 (422.089 sec)
# INFO:tensorflow:global_step/sec: 0.197673
# INFO:tensorflow:loss = 0.236283, step = 23501 (505.887 sec)
# INFO:tensorflow:Saving checkpoints for 23600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.1922
# INFO:tensorflow:loss = 0.30697823, step = 23601 (520.290 sec)
# INFO:tensorflow:global_step/sec: 0.232305
# INFO:tensorflow:loss = 0.25236067, step = 23701 (430.468 sec)
# INFO:tensorflow:Saving checkpoints for 23800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.245416
# INFO:tensorflow:loss = 0.25151753, step = 23801 (407.471 sec)
# INFO:tensorflow:global_step/sec: 0.243769
# INFO:tensorflow:loss = 0.17393799, step = 23901 (410.226 sec)
# INFO:tensorflow:Saving checkpoints for 24000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.246844
# INFO:tensorflow:loss = 0.21431234, step = 24001 (405.114 sec)
# INFO:tensorflow:global_step/sec: 0.236127
# INFO:tensorflow:loss = 0.34108767, step = 24101 (423.501 sec)
# INFO:tensorflow:Saving checkpoints for 24200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.244996
# INFO:tensorflow:loss = 0.2591333, step = 24201 (408.169 sec)
# INFO:tensorflow:global_step/sec: 0.244548
# INFO:tensorflow:loss = 0.16861673, step = 24301 (408.918 sec)
# INFO:tensorflow:Saving checkpoints for 24400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.24008
# INFO:tensorflow:loss = 0.22620639, step = 24401 (416.527 sec)
# INFO:tensorflow:global_step/sec: 0.241909
# INFO:tensorflow:loss = 0.26126888, step = 24501 (413.378 sec)
# INFO:tensorflow:Saving checkpoints for 24600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.248163
# INFO:tensorflow:loss = 0.287855, step = 24601 (402.962 sec)
# INFO:tensorflow:global_step/sec: 0.247178
# INFO:tensorflow:loss = 0.2524246, step = 24701 (404.568 sec)
# INFO:tensorflow:Saving checkpoints for 24800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.243848
# INFO:tensorflow:loss = 0.2478711, step = 24801 (410.091 sec)
# INFO:tensorflow:global_step/sec: 0.243919
# INFO:tensorflow:loss = 0.19296095, step = 24901 (409.973 sec)
# INFO:tensorflow:Saving checkpoints for 25000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.247167
# INFO:tensorflow:loss = 0.23715542, step = 25001 (404.584 sec)
# INFO:tensorflow:global_step/sec: 0.244946
# INFO:tensorflow:loss = 0.23466788, step = 25101 (408.254 sec)
# INFO:tensorflow:Saving checkpoints for 25200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.252435
# INFO:tensorflow:loss = 0.260427, step = 25201 (396.141 sec)
# INFO:tensorflow:global_step/sec: 0.247549
# INFO:tensorflow:loss = 0.18921776, step = 25301 (403.960 sec)
# INFO:tensorflow:Saving checkpoints for 25400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.251737
# INFO:tensorflow:loss = 0.20914109, step = 25401 (397.240 sec)
# INFO:tensorflow:global_step/sec: 0.248238
# INFO:tensorflow:loss = 0.22087117, step = 25501 (402.839 sec)
# INFO:tensorflow:Saving checkpoints for 25600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.248652
# INFO:tensorflow:loss = 0.277332, step = 25601 (402.168 sec)
# INFO:tensorflow:global_step/sec: 0.252901
# INFO:tensorflow:loss = 0.20495388, step = 25701 (395.411 sec)
# INFO:tensorflow:Saving checkpoints for 25800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.253038
# INFO:tensorflow:loss = 0.22534865, step = 25801 (395.197 sec)
# INFO:tensorflow:global_step/sec: 0.248069
# INFO:tensorflow:loss = 0.21944457, step = 25901 (403.114 sec)
# INFO:tensorflow:Saving checkpoints for 26000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.249664
# INFO:tensorflow:loss = 0.2940582, step = 26001 (400.538 sec)
# INFO:tensorflow:global_step/sec: 0.248251
# INFO:tensorflow:loss = 0.20433298, step = 26101 (402.818 sec)
# INFO:tensorflow:Saving checkpoints for 26200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.248321
# INFO:tensorflow:loss = 0.24202897, step = 26201 (402.704 sec)
# INFO:tensorflow:global_step/sec: 0.250006
# INFO:tensorflow:loss = 0.21791758, step = 26301 (399.991 sec)
# INFO:tensorflow:Saving checkpoints for 26400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.247073
# INFO:tensorflow:loss = 0.16613317, step = 26401 (404.739 sec)
# INFO:tensorflow:global_step/sec: 0.247155
# INFO:tensorflow:loss = 0.25358424, step = 26501 (404.605 sec)
# INFO:tensorflow:Saving checkpoints for 26600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.247641
# INFO:tensorflow:loss = 0.28071055, step = 26601 (403.810 sec)
# INFO:tensorflow:global_step/sec: 0.244266
# INFO:tensorflow:loss = 0.25312164, step = 26701 (409.390 sec)
# INFO:tensorflow:Saving checkpoints for 26800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.248486
# INFO:tensorflow:loss = 0.24115941, step = 26801 (402.438 sec)
# INFO:tensorflow:global_step/sec: 0.247527
# INFO:tensorflow:loss = 0.24296737, step = 26901 (403.996 sec)
# INFO:tensorflow:Saving checkpoints for 27000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.249847
# INFO:tensorflow:loss = 0.22665815, step = 27001 (400.244 sec)
# INFO:tensorflow:global_step/sec: 0.248511
# INFO:tensorflow:loss = 0.278541, step = 27101 (402.396 sec)
# INFO:tensorflow:Saving checkpoints for 27200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.250389
# INFO:tensorflow:loss = 0.26416868, step = 27201 (399.378 sec)
# INFO:tensorflow:global_step/sec: 0.246591
# INFO:tensorflow:loss = 0.2513246, step = 27301 (405.530 sec)
# INFO:tensorflow:Saving checkpoints for 27400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.251762
# INFO:tensorflow:loss = 0.29574642, step = 27401 (397.199 sec)
# INFO:tensorflow:global_step/sec: 0.249966
# INFO:tensorflow:loss = 0.2894465, step = 27501 (400.054 sec)
# INFO:tensorflow:Saving checkpoints for 27600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.258468
# INFO:tensorflow:loss = 0.19871618, step = 27601 (386.896 sec)
# INFO:tensorflow:global_step/sec: 0.265803
# INFO:tensorflow:loss = 0.19476502, step = 27701 (376.218 sec)
# INFO:tensorflow:Saving checkpoints for 27800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.265907
# INFO:tensorflow:loss = 0.15053476, step = 27801 (376.072 sec)
# INFO:tensorflow:global_step/sec: 0.26285
# INFO:tensorflow:loss = 0.2533057, step = 27901 (380.445 sec)
# INFO:tensorflow:Saving checkpoints for 28000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261012
# INFO:tensorflow:loss = 0.23791918, step = 28001 (383.123 sec)
# INFO:tensorflow:global_step/sec: 0.263128
# INFO:tensorflow:loss = 0.21998869, step = 28101 (380.044 sec)
# INFO:tensorflow:Saving checkpoints for 28200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.262208
# INFO:tensorflow:loss = 0.2528161, step = 28201 (381.376 sec)
# INFO:tensorflow:global_step/sec: 0.261322
# INFO:tensorflow:loss = 0.25906402, step = 28301 (382.669 sec)
# INFO:tensorflow:Saving checkpoints for 28400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261488
# INFO:tensorflow:loss = 0.26439884, step = 28401 (382.427 sec)
# INFO:tensorflow:global_step/sec: 0.261213
# INFO:tensorflow:loss = 0.27187878, step = 28501 (382.829 sec)
# INFO:tensorflow:Saving checkpoints for 28600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.257949
# INFO:tensorflow:loss = 0.2254091, step = 28601 (387.673 sec)
# INFO:tensorflow:global_step/sec: 0.262383
# INFO:tensorflow:loss = 0.26472157, step = 28701 (381.122 sec)
# INFO:tensorflow:Saving checkpoints for 28800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.26693
# INFO:tensorflow:loss = 0.27042183, step = 28801 (374.629 sec)
# INFO:tensorflow:global_step/sec: 0.265622
# INFO:tensorflow:loss = 0.41761035, step = 28901 (376.475 sec)
# INFO:tensorflow:Saving checkpoints for 29000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.257312
# INFO:tensorflow:loss = 0.20936802, step = 29001 (388.634 sec)
# INFO:tensorflow:global_step/sec: 0.261469
# INFO:tensorflow:loss = 0.29738602, step = 29101 (382.455 sec)
# INFO:tensorflow:Saving checkpoints for 29200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.262175
# INFO:tensorflow:loss = 0.23519835, step = 29201 (381.425 sec)
# INFO:tensorflow:global_step/sec: 0.259396
# INFO:tensorflow:loss = 0.15678169, step = 29301 (385.511 sec)
# INFO:tensorflow:Saving checkpoints for 29400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.266134
# INFO:tensorflow:loss = 0.20382836, step = 29401 (375.750 sec)
# INFO:tensorflow:global_step/sec: 0.261828
# INFO:tensorflow:loss = 0.16972867, step = 29501 (381.930 sec)
# INFO:tensorflow:Saving checkpoints for 29600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.265268
# INFO:tensorflow:loss = 0.27882588, step = 29601 (376.978 sec)
# INFO:tensorflow:global_step/sec: 0.267783
# INFO:tensorflow:loss = 0.23758666, step = 29701 (373.437 sec)
# INFO:tensorflow:Saving checkpoints for 29800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.266832
# INFO:tensorflow:loss = 0.19122675, step = 29801 (374.767 sec)
# INFO:tensorflow:global_step/sec: 0.265355
# INFO:tensorflow:loss = 0.22210766, step = 29901 (376.854 sec)
# INFO:tensorflow:Saving checkpoints for 30000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.265883
# INFO:tensorflow:loss = 0.19015051, step = 30001 (376.105 sec)
# INFO:tensorflow:global_step/sec: 0.262151
# INFO:tensorflow:loss = 0.21063922, step = 30101 (381.460 sec)
# INFO:tensorflow:Saving checkpoints for 30200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.262784
# INFO:tensorflow:loss = 0.1826089, step = 30201 (380.541 sec)
# INFO:tensorflow:global_step/sec: 0.258635
# INFO:tensorflow:loss = 0.24716838, step = 30301 (386.645 sec)
# INFO:tensorflow:Saving checkpoints for 30400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.260209
# INFO:tensorflow:loss = 0.21797505, step = 30401 (384.306 sec)
# INFO:tensorflow:global_step/sec: 0.260728
# INFO:tensorflow:loss = 0.3039512, step = 30501 (383.542 sec)
# INFO:tensorflow:Saving checkpoints for 30600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.265584
# INFO:tensorflow:loss = 0.2370916, step = 30601 (376.529 sec)
# INFO:tensorflow:global_step/sec: 0.266531
# INFO:tensorflow:loss = 0.22929099, step = 30701 (375.191 sec)
# INFO:tensorflow:Saving checkpoints for 30800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261947
# INFO:tensorflow:loss = 0.2586285, step = 30801 (381.756 sec)
# INFO:tensorflow:global_step/sec: 0.263499
# INFO:tensorflow:loss = 0.26096606, step = 30901 (379.508 sec)
# INFO:tensorflow:Saving checkpoints for 31000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.263109
# INFO:tensorflow:loss = 0.2762036, step = 31001 (380.070 sec)
# INFO:tensorflow:global_step/sec: 0.26634
# INFO:tensorflow:loss = 0.28451115, step = 31101 (375.460 sec)
# INFO:tensorflow:Saving checkpoints for 31200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.255786
# INFO:tensorflow:loss = 0.275855, step = 31201 (390.951 sec)
# INFO:tensorflow:global_step/sec: 0.25866
# INFO:tensorflow:loss = 0.24255344, step = 31301 (386.608 sec)
# INFO:tensorflow:Saving checkpoints for 31400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.257914
# INFO:tensorflow:loss = 0.20386326, step = 31401 (387.727 sec)
# INFO:tensorflow:global_step/sec: 0.26274
# INFO:tensorflow:loss = 0.21720661, step = 31501 (380.605 sec)
# INFO:tensorflow:Saving checkpoints for 31600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.262463
# INFO:tensorflow:loss = 0.20784867, step = 31601 (381.007 sec)
# INFO:tensorflow:global_step/sec: 0.262909
# INFO:tensorflow:loss = 0.19815217, step = 31701 (380.359 sec)
# INFO:tensorflow:Saving checkpoints for 31800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261808
# INFO:tensorflow:loss = 0.20475653, step = 31801 (381.959 sec)
# INFO:tensorflow:global_step/sec: 0.264824
# INFO:tensorflow:loss = 0.21299312, step = 31901 (377.610 sec)
# INFO:tensorflow:Saving checkpoints for 32000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.265242
# INFO:tensorflow:loss = 0.27972078, step = 32001 (377.014 sec)
# INFO:tensorflow:global_step/sec: 0.262286
# INFO:tensorflow:loss = 0.25538233, step = 32101 (381.263 sec)
# INFO:tensorflow:Saving checkpoints for 32200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.265731
# INFO:tensorflow:loss = 0.21623634, step = 32201 (376.320 sec)
# INFO:tensorflow:global_step/sec: 0.26304
# INFO:tensorflow:loss = 0.24004814, step = 32301 (380.171 sec)
# INFO:tensorflow:Saving checkpoints for 32400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.262061
# INFO:tensorflow:loss = 0.17693281, step = 32401 (381.591 sec)
# INFO:tensorflow:global_step/sec: 0.264838
# INFO:tensorflow:loss = 0.34190637, step = 32501 (377.589 sec)
# INFO:tensorflow:Saving checkpoints for 32600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.265861
# INFO:tensorflow:loss = 0.17491016, step = 32601 (376.137 sec)
# INFO:tensorflow:global_step/sec: 0.260397
# INFO:tensorflow:loss = 0.25227088, step = 32701 (384.030 sec)
# INFO:tensorflow:Saving checkpoints for 32800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.260001
# INFO:tensorflow:loss = 0.18005918, step = 32801 (384.614 sec)
# INFO:tensorflow:global_step/sec: 0.261686
# INFO:tensorflow:loss = 0.23040783, step = 32901 (382.138 sec)
# INFO:tensorflow:Saving checkpoints for 33000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.260989
# INFO:tensorflow:loss = 0.25803357, step = 33001 (383.158 sec)
# INFO:tensorflow:global_step/sec: 0.262864
# INFO:tensorflow:loss = 0.20057508, step = 33101 (380.425 sec)
# INFO:tensorflow:Saving checkpoints for 33200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.264245
# INFO:tensorflow:loss = 0.2738755, step = 33201 (378.436 sec)
# INFO:tensorflow:global_step/sec: 0.260719
# INFO:tensorflow:loss = 0.21859422, step = 33301 (383.555 sec)
# INFO:tensorflow:Saving checkpoints for 33400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.266235
# INFO:tensorflow:loss = 0.19510879, step = 33401 (375.607 sec)
# INFO:tensorflow:global_step/sec: 0.266071
# INFO:tensorflow:loss = 0.2613263, step = 33501 (375.839 sec)
# INFO:tensorflow:Saving checkpoints for 33600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.263872
# INFO:tensorflow:loss = 0.2430284, step = 33601 (378.971 sec)
# INFO:tensorflow:global_step/sec: 0.264201
# INFO:tensorflow:loss = 0.22350965, step = 33701 (378.501 sec)
# INFO:tensorflow:Saving checkpoints for 33800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.244652
# INFO:tensorflow:loss = 0.18097003, step = 33801 (408.744 sec)
# INFO:tensorflow:global_step/sec: 0.260374
# INFO:tensorflow:loss = 0.2835511, step = 33901 (384.063 sec)
# ...
# INFO:tensorflow:loss = 0.24519439, step = 95301 (374.699 sec)
# INFO:tensorflow:Saving checkpoints for 95400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.254288
# INFO:tensorflow:loss = 0.23844203, step = 95401 (393.254 sec)
# INFO:tensorflow:global_step/sec: 0.258071
# INFO:tensorflow:loss = 0.23044176, step = 95501 (387.490 sec)
# INFO:tensorflow:Saving checkpoints for 95600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.263394
# INFO:tensorflow:loss = 0.30291066, step = 95601 (379.659 sec)
# INFO:tensorflow:global_step/sec: 0.26109
# INFO:tensorflow:loss = 0.32750002, step = 95701 (383.009 sec)
# INFO:tensorflow:Saving checkpoints for 95800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.263986
# INFO:tensorflow:loss = 0.20799771, step = 95801 (378.808 sec)
# INFO:tensorflow:global_step/sec: 0.267767
# INFO:tensorflow:loss = 0.29151252, step = 95901 (373.460 sec)
# INFO:tensorflow:Saving checkpoints for 96000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.268421
# INFO:tensorflow:loss = 0.30115247, step = 96001 (372.549 sec)
# INFO:tensorflow:global_step/sec: 0.265932
# INFO:tensorflow:loss = 0.25555852, step = 96101 (376.036 sec)
# INFO:tensorflow:Saving checkpoints for 96200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.27009
# INFO:tensorflow:loss = 0.31853452, step = 96201 (370.247 sec)
# INFO:tensorflow:global_step/sec: 0.268866
# INFO:tensorflow:loss = 0.29455197, step = 96301 (371.932 sec)
# INFO:tensorflow:Saving checkpoints for 96400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.290006
# INFO:tensorflow:loss = 0.30674556, step = 96401 (344.821 sec)
# INFO:tensorflow:global_step/sec: 0.274557
# INFO:tensorflow:loss = 0.25560948, step = 96501 (364.223 sec)
# INFO:tensorflow:Saving checkpoints for 96600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.259479
# INFO:tensorflow:loss = 0.2668605, step = 96601 (385.388 sec)
# INFO:tensorflow:global_step/sec: 0.264104
# INFO:tensorflow:loss = 0.2323883, step = 96701 (378.639 sec)
# INFO:tensorflow:Saving checkpoints for 96800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.260368
# INFO:tensorflow:loss = 0.2718917, step = 96801 (384.071 sec)
# INFO:tensorflow:global_step/sec: 0.261926
# INFO:tensorflow:loss = 0.3055564, step = 96901 (381.787 sec)
# INFO:tensorflow:Saving checkpoints for 97000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.263734
# INFO:tensorflow:loss = 0.1962697, step = 97001 (379.170 sec)
# INFO:tensorflow:global_step/sec: 0.260606
# INFO:tensorflow:loss = 0.29889482, step = 97101 (383.721 sec)
# INFO:tensorflow:Saving checkpoints for 97200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.260064
# INFO:tensorflow:loss = 0.25729746, step = 97201 (384.522 sec)
# INFO:tensorflow:global_step/sec: 0.264794
# INFO:tensorflow:loss = 0.25644588, step = 97301 (377.652 sec)
# INFO:tensorflow:Saving checkpoints for 97400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.26164
# INFO:tensorflow:loss = 0.29606858, step = 97401 (382.205 sec)
# INFO:tensorflow:global_step/sec: 0.263641
# INFO:tensorflow:loss = 0.2546397, step = 97501 (379.303 sec)
# INFO:tensorflow:Saving checkpoints for 97600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.263597
# INFO:tensorflow:loss = 0.28651282, step = 97601 (379.367 sec)
# INFO:tensorflow:global_step/sec: 0.262886
# INFO:tensorflow:loss = 0.21183448, step = 97701 (380.392 sec)
# INFO:tensorflow:Saving checkpoints for 97800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261856
# INFO:tensorflow:loss = 0.26560816, step = 97801 (381.889 sec)
# INFO:tensorflow:global_step/sec: 0.261842
# INFO:tensorflow:loss = 0.33384815, step = 97901 (381.909 sec)
# INFO:tensorflow:Saving checkpoints for 98000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.258516
# INFO:tensorflow:loss = 0.23296292, step = 98001 (386.823 sec)
# INFO:tensorflow:global_step/sec: 0.262591
# INFO:tensorflow:loss = 0.20157808, step = 98101 (380.820 sec)
# INFO:tensorflow:Saving checkpoints for 98200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261395
# INFO:tensorflow:loss = 0.18066409, step = 98201 (382.563 sec)
# INFO:tensorflow:global_step/sec: 0.264795
# INFO:tensorflow:loss = 0.2268558, step = 98301 (377.650 sec)
# INFO:tensorflow:Saving checkpoints for 98400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.263663
# INFO:tensorflow:loss = 0.18350114, step = 98401 (379.274 sec)
# INFO:tensorflow:global_step/sec: 0.247372
# INFO:tensorflow:loss = 0.34785345, step = 98501 (404.248 sec)
# INFO:tensorflow:Saving checkpoints for 98600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.260997
# INFO:tensorflow:loss = 0.24053836, step = 98601 (383.146 sec)
# INFO:tensorflow:global_step/sec: 0.264204
# INFO:tensorflow:loss = 0.21284166, step = 98701 (378.496 sec)
# INFO:tensorflow:Saving checkpoints for 98800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.265164
# INFO:tensorflow:loss = 0.25043866, step = 98801 (377.125 sec)
# INFO:tensorflow:global_step/sec: 0.252707
# INFO:tensorflow:loss = 0.30133662, step = 98901 (395.716 sec)
# INFO:tensorflow:Saving checkpoints for 99000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.255287
# INFO:tensorflow:loss = 0.30507082, step = 99001 (391.717 sec)
# INFO:tensorflow:global_step/sec: 0.261236
# INFO:tensorflow:loss = 0.23755243, step = 99101 (382.795 sec)
# INFO:tensorflow:Saving checkpoints for 99200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.265813
# INFO:tensorflow:loss = 0.22483741, step = 99201 (376.204 sec)
# INFO:tensorflow:global_step/sec: 0.265966
# INFO:tensorflow:loss = 0.2577505, step = 99301 (375.989 sec)
# INFO:tensorflow:Saving checkpoints for 99400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261903
# INFO:tensorflow:loss = 0.24072316, step = 99401 (381.821 sec)
# INFO:tensorflow:global_step/sec: 0.263835
# INFO:tensorflow:loss = 0.24633366, step = 99501 (379.025 sec)
# INFO:tensorflow:Saving checkpoints for 99600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.263208
# INFO:tensorflow:loss = 0.24503453, step = 99601 (379.928 sec)
# INFO:tensorflow:global_step/sec: 0.263217
# INFO:tensorflow:loss = 0.2720677, step = 99701 (379.914 sec)
# INFO:tensorflow:Saving checkpoints for 99800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261588
# INFO:tensorflow:loss = 0.2991102, step = 99801 (382.281 sec)
# INFO:tensorflow:global_step/sec: 0.264124
# INFO:tensorflow:loss = 0.26884064, step = 99901 (378.610 sec)
# INFO:tensorflow:Saving checkpoints for 100000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.266172
# INFO:tensorflow:loss = 0.2292118, step = 100001 (375.697 sec)
# INFO:tensorflow:global_step/sec: 0.267857
# INFO:tensorflow:loss = 0.24749321, step = 100101 (373.333 sec)
# INFO:tensorflow:Saving checkpoints for 100200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.262805
# INFO:tensorflow:loss = 0.33005875, step = 100201 (380.511 sec)
# INFO:tensorflow:global_step/sec: 0.263842
# INFO:tensorflow:loss = 0.23933008, step = 100301 (379.014 sec)
# INFO:tensorflow:Saving checkpoints for 100400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.264048
# INFO:tensorflow:loss = 0.23880167, step = 100401 (378.718 sec)
# INFO:tensorflow:global_step/sec: 0.267087
# INFO:tensorflow:loss = 0.23184372, step = 100501 (374.410 sec)
# INFO:tensorflow:Saving checkpoints for 100600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.262114
# INFO:tensorflow:loss = 0.24320719, step = 100601 (381.513 sec)
# INFO:tensorflow:global_step/sec: 0.261296
# INFO:tensorflow:loss = 0.27470753, step = 100701 (382.708 sec)
# INFO:tensorflow:Saving checkpoints for 100800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.267195
# INFO:tensorflow:loss = 0.2538987, step = 100801 (374.259 sec)
# INFO:tensorflow:global_step/sec: 0.262508
# INFO:tensorflow:loss = 0.2995469, step = 100901 (380.941 sec)
# INFO:tensorflow:Saving checkpoints for 101000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261497
# INFO:tensorflow:loss = 0.24603398, step = 101001 (382.413 sec)
# INFO:tensorflow:global_step/sec: 0.265091
# INFO:tensorflow:loss = 0.17128345, step = 101101 (377.229 sec)
# INFO:tensorflow:Saving checkpoints for 101200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.262855
# INFO:tensorflow:loss = 0.24111769, step = 101201 (380.438 sec)
# INFO:tensorflow:global_step/sec: 0.263227
# INFO:tensorflow:loss = 0.27284774, step = 101301 (379.901 sec)
# INFO:tensorflow:Saving checkpoints for 101400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261312
# INFO:tensorflow:loss = 0.220354, step = 101401 (382.684 sec)
# INFO:tensorflow:global_step/sec: 0.260041
# INFO:tensorflow:loss = 0.2974161, step = 101501 (384.554 sec)
# INFO:tensorflow:Saving checkpoints for 101600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.255413
# INFO:tensorflow:loss = 0.31406596, step = 101601 (391.522 sec)
# INFO:tensorflow:global_step/sec: 0.263642
# INFO:tensorflow:loss = 0.39547467, step = 101701 (379.302 sec)
# INFO:tensorflow:Saving checkpoints for 101800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.258617
# INFO:tensorflow:loss = 0.29011923, step = 101801 (386.673 sec)
# INFO:tensorflow:global_step/sec: 0.262088
# INFO:tensorflow:loss = 0.28981787, step = 101901 (381.551 sec)
# INFO:tensorflow:Saving checkpoints for 102000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.26303
# INFO:tensorflow:loss = 0.23010397, step = 102001 (380.186 sec)
# INFO:tensorflow:global_step/sec: 0.263631
# INFO:tensorflow:loss = 0.2540026, step = 102101 (379.318 sec)
# INFO:tensorflow:Saving checkpoints for 102200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.263612
# INFO:tensorflow:loss = 0.27770263, step = 102201 (379.346 sec)
# INFO:tensorflow:global_step/sec: 0.262095
# INFO:tensorflow:loss = 0.23810169, step = 102301 (381.541 sec)
# INFO:tensorflow:Saving checkpoints for 102400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.26472
# INFO:tensorflow:loss = 0.32086766, step = 102401 (377.758 sec)
# INFO:tensorflow:global_step/sec: 0.26272
# INFO:tensorflow:loss = 0.28387025, step = 102501 (380.633 sec)
# INFO:tensorflow:Saving checkpoints for 102600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261684
# INFO:tensorflow:loss = 0.24171162, step = 102601 (382.141 sec)
# INFO:tensorflow:global_step/sec: 0.262612
# INFO:tensorflow:loss = 0.2178066, step = 102701 (380.789 sec)
# INFO:tensorflow:Saving checkpoints for 102800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.260166
# INFO:tensorflow:loss = 0.292066, step = 102801 (384.370 sec)
# INFO:tensorflow:global_step/sec: 0.260183
# INFO:tensorflow:loss = 0.2767839, step = 102901 (384.345 sec)
# INFO:tensorflow:Saving checkpoints for 103000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.261989
# INFO:tensorflow:loss = 0.2445983, step = 103001 (381.695 sec)
# INFO:tensorflow:global_step/sec: 0.263169
# INFO:tensorflow:loss = 0.2442921, step = 103101 (379.985 sec)
# INFO:tensorflow:Saving checkpoints for 103200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.263997
# INFO:tensorflow:loss = 0.20362969, step = 103201 (378.792 sec)
# INFO:tensorflow:global_step/sec: 0.262082
# INFO:tensorflow:loss = 0.2595548, step = 103301 (381.560 sec)
# INFO:tensorflow:Saving checkpoints for 103400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.259853
# INFO:tensorflow:loss = 0.285427, step = 103401 (384.833 sec)
# INFO:tensorflow:global_step/sec: 0.260467
# INFO:tensorflow:loss = 0.24028617, step = 103501 (383.926 sec)
# INFO:tensorflow:Saving checkpoints for 103600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.26588
# INFO:tensorflow:loss = 0.18228386, step = 103601 (376.110 sec)
# INFO:tensorflow:global_step/sec: 0.26519
# INFO:tensorflow:loss = 0.23774318, step = 103701 (377.089 sec)
# INFO:tensorflow:Saving checkpoints for 103800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.26157
# INFO:tensorflow:loss = 0.28540128, step = 103801 (382.306 sec)
# INFO:tensorflow:global_step/sec: 0.259719
# INFO:tensorflow:loss = 0.22288854, step = 103901 (385.032 sec)
# INFO:tensorflow:Saving checkpoints for 104000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.264784
# INFO:tensorflow:loss = 0.2652003, step = 104001 (377.667 sec)
# INFO:tensorflow:global_step/sec: 0.261758
# INFO:tensorflow:loss = 0.25137034, step = 104101 (382.033 sec)
# INFO:tensorflow:Saving checkpoints for 104200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.253849
# INFO:tensorflow:loss = 0.27834472, step = 104201 (393.935 sec)
# INFO:tensorflow:global_step/sec: 0.24923
# INFO:tensorflow:loss = 0.2583986, step = 104301 (401.235 sec)
# INFO:tensorflow:Saving checkpoints for 104400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.25579
# INFO:tensorflow:loss = 0.19879667, step = 104401 (390.945 sec)
# INFO:tensorflow:global_step/sec: 0.252845
# INFO:tensorflow:loss = 0.2929583, step = 104501 (395.499 sec)
# INFO:tensorflow:Saving checkpoints for 104600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.246986
# INFO:tensorflow:loss = 0.22626609, step = 104601 (404.881 sec)
# INFO:tensorflow:global_step/sec: 0.249664
# INFO:tensorflow:loss = 0.24658373, step = 104701 (400.539 sec)
# INFO:tensorflow:Saving checkpoints for 104800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.247762
# INFO:tensorflow:loss = 0.23157537, step = 104801 (403.613 sec)
# INFO:tensorflow:global_step/sec: 0.247889
# INFO:tensorflow:loss = 0.2414747, step = 104901 (403.406 sec)
# INFO:tensorflow:Saving checkpoints for 105000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.246909
# INFO:tensorflow:loss = 0.23610625, step = 105001 (405.008 sec)
# INFO:tensorflow:global_step/sec: 0.248318
# INFO:tensorflow:loss = 0.22445187, step = 105101 (402.710 sec)
# INFO:tensorflow:Saving checkpoints for 105200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.247895
# INFO:tensorflow:loss = 0.27745554, step = 105201 (403.396 sec)
# INFO:tensorflow:global_step/sec: 0.247138
# INFO:tensorflow:loss = 0.22977541, step = 105301 (404.632 sec)
# INFO:tensorflow:Saving checkpoints for 105400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.24739
# INFO:tensorflow:loss = 0.29189384, step = 105401 (404.219 sec)
# INFO:tensorflow:global_step/sec: 0.243762
# INFO:tensorflow:loss = 0.2545232, step = 105501 (410.236 sec)
# INFO:tensorflow:Saving checkpoints for 105600 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.250586
# INFO:tensorflow:loss = 0.25204152, step = 105601 (399.064 sec)
# INFO:tensorflow:global_step/sec: 0.249887
# INFO:tensorflow:loss = 0.24476154, step = 105701 (400.181 sec)
# INFO:tensorflow:Saving checkpoints for 105800 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.248993
# INFO:tensorflow:loss = 0.20708495, step = 105801 (401.618 sec)
# INFO:tensorflow:global_step/sec: 0.245755
# INFO:tensorflow:loss = 0.27518514, step = 105901 (406.909 sec)
# INFO:tensorflow:Saving checkpoints for 106000 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.251024
# INFO:tensorflow:loss = 0.23214978, step = 106001 (398.367 sec)
# INFO:tensorflow:global_step/sec: 0.249165
# INFO:tensorflow:loss = 0.2668392, step = 106101 (401.340 sec)
# INFO:tensorflow:Saving checkpoints for 106200 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.25027
# INFO:tensorflow:loss = 0.30265158, step = 106201 (399.568 sec)
# INFO:tensorflow:global_step/sec: 0.24534
# INFO:tensorflow:loss = 0.2457736, step = 106301 (407.598 sec)
# INFO:tensorflow:Saving checkpoints for 106400 into project_v2_2/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.245296
# INFO:tensorflow:loss = 0.2131739, step = 106401 (407.670 sec)
# INFO:tensorflow:global_step/sec: 0.243393
# INFO:tensorflow:loss = 0.25565267, step = 106501 (410.859 sec)

# %%
# обучение и валидация
eval_result = model.evaluate(lambda: input_fn('eval.txt', params=params, mode='eval'))

# %%
# дешифровка 
def placement_punctuation(data, mode='from_list'):
    '''
        функция расстановки пунктуации (.,!,?:;)
        mode -  тип подоваемых данных:
                если 'from_list' то data должна быть массивом строк
                если 'from_file' то data должна быть путем до файла
        data -  либо строка, либо массив строк, в зависимости от mode
        
        -----------------------------------------------------------------
        пример:
        
        test_data = [
            'Он уже должен был прийти обратно Почему он не возвращается',
            'Я не знаю Аэтпио не видит ничего кроме мертвых камней'
        ]
        placement_punctuation(test_data)
        -----------------------------------------------------------------
        пример:
        
        placement_punctuation('test.txt', mode='from_file')
        -----------------------------------------------------------------
    '''
    d = {1:2922, 2:2921, 3:2978, 4:2985, 5:2947, 6:2963, 7:2936}
    if mode == 'from_file':
        prediction = model.predict(lambda: input_fn(data, params=params, mode='predicted'))
    else:
        prediction = model.predict(lambda: test_input_fn(data, params=params))
    for x in prediction:
        a = []
        for i in range(x['lengths']):
            a.append(x['sequences'][i])
            if x['prediction'][i] != 0:
                a.append(d[x['prediction'][i]])
        print(bpemb_ru.decode_ids(np.array(a)))

# %%
test_data = [
    'он уже должен был прийти обратно почему он не возвращается',
    'я не знаю аэтпио не видит ничего кроме мертвых камней'
]
placement_punctuation(test_data)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from project_v2/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# он уже должен был прийти обратно. почему он не возвращается?
# я не знаю, аэтпио не видит ничего, кроме мертвых камней.

# %%
placement_punctuation('test.txt', mode='from_file')
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from project_v2/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# он уже должен был прийти обратно. почему он не возвращается?
# я не знаю, аэтпио не видит ничего, кроме мертвых камней.
# и ютипа тоже. почему взгляд хранителей не может проникнуть глубже?
# кто знает? ариман не смел даже самому себе признаться, насколько сильно он встревожен.
# я думал, ты сумеешь туда заглянуть. в конце концов, ты же корвид.
# здесь это не поможет.
# тебе легко говорить, но не всем же быть павонидами. кое-кому приходится бороться с жарой собственными средствами.
# с каких это пор ты овладел мастерством атенейцев?
# мне этого не требуется. и так понятно, что вы оба встревожены. это очевидно.

# %%
placement_punctuation('barmaglot.txt', mode='from_file')
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from project_v2/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# варкалось. хливкие шорьки пырялись по нове и хрюкотали зелюки, как мюмзики в мове.
# о, бойся, бармаглота сын!
# он так свирлеп и дик, а в глуще рымит исполин злопастный брандашмыг, но взял он меч и взял. он щит высоких полон дум.
# в глущобу путь его лежит под дерево тумтум.
# он стал под дерево и ждет, и вдруг граахнул. гром летит ужасный бармаглот и пылкает огнем.
# раз-два раз-два горит трова взы-взы стрижает меч, ува ува и голова барабардает с плеч.
# о, светозарный мальчик мой! ты победил в бою о храброславленный герой. хвалу тебе пою.
# варкалось. хливкие шорьки пырялись по нове и хрюкотали зелюки, как мюмзики в мове.
